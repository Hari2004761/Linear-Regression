# %%
import tensorflow as tf
import pandas as pd
import keras
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from tensorflow.keras import datasets
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
# !pip install opendatasets
import opendatasets as od
od.download("https://www.kaggle.com/datasets/shalmamuji/electricity-cost-prediction-dataset")
# Out:
# ...
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: hari20321
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/shalmamuji/electricity-cost-prediction-dataset
# ...
# 100%|██████████| 154k/154k [00:00<00:00, 209MB/s]

# %%
df=pd.read_csv("/content/electricity-cost-prediction-dataset/electricity_cost_dataset.csv")

# %%
df.head()
# Out:
#    site area structure type  water consumption  recycling rate  \
# 0       1360      Mixed-use             2519.0              69
# 1       4272      Mixed-use             2324.0              50
# 2       3592      Mixed-use             2701.0              20
# 3        966    Residential             1000.0              13
# 4       4926    Residential             5990.0              23
#
#    utilisation rate  air qality index  issue reolution time  resident count  \
# 0                52               188                     1              72
# 1                76               165                    65             261
# 2                94               198                    39             117
# 3                60                74                     3              35
# 4                65                32                    57             185
#
#    electricity cost
# 0            1420.0
# 1            3298.0
# 2            3115.0
# 3            1575.0
# 4            4301.0

# %%
x=df.drop("electricity cost",axis=1)
x=pd.get_dummies(x)
y=df["electricity cost"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9212688972573702

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([3114.30295348, 3733.38605633, 1799.14985398, ..., 2711.93957828,
#        2525.20248543, 4294.22475162])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

y_pred = model.predict(x_test)

print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("R² Score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error (MAE): 242.48763905054648
# Mean Squared Error (MSE): 96008.57216413095
# R² Score: 0.9212688972573702
